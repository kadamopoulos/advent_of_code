# %%
import re

# %%
input_data = "385350926-385403705,48047-60838,6328350434-6328506208,638913-698668,850292-870981,656-1074,742552-796850,4457-6851,138-206,4644076-4851885,3298025-3353031,8594410816-8594543341,396-498,1558-2274,888446-916096,12101205-12154422,2323146444-2323289192,37-57,101-137,46550018-46679958,79-96,317592-341913,495310-629360,33246-46690,14711-22848,1-17,2850-4167,3723700171-3723785996,190169-242137,272559-298768,275-365,7697-11193,61-78,75373-110112,425397-451337,9796507-9899607,991845-1013464,77531934-77616074"
test_data = "11-22,95-115,998-1012,1188511880-1188511890,222220-222224,1698522-1698528,446443-446449,38593856-38593862,565653-565659,824824821-824824827,2121212118-2121212124"

# %%
ranges = [list(range(int(r.split("-")[0]), int(r.split("-")[1])+1)) for r in input_data.split(",")]

# %%
double_pattern = "^(.+?)\\1{1}$"
multiple_pattern = "^(.+?)\\1+$"

# %%
if re.match(multiple_pattern, "23232323"):
    print("yes")
# Out:
# yes

# %%
double_sum = 0

for rang in ranges:
    for i in rang:
        if re.match(double_pattern, str(i)):
            double_sum += i

double_sum
# Out:
# 28846518423

# %%
double_sum = 0

for rang in ranges:
    for i in rang:
        if re.match(multiple_pattern, str(i)):
            double_sum += i

double_sum
# Out:
# 31578210022

# %%
invalid_ids
# Out:
# []

# %%
7%1
# Out:
# 0
